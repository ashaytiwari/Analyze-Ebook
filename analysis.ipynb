# %% [markdown]
# # Load the book

# %%
with open("miracle_in_the_andes.txt", "r", encoding="utf-8") as file:
    book = file.read()

# %% [markdown]
# # How many chapters in the book?

# %% [markdown]
# ### With string methods

# %%
print(book.count("Chapter"))
# Out:
# 11

# %% [markdown]
# ### With regex

# %%
import re

pattern = re.compile("Chapter [0-9]+")

chapter_list = re.findall(pattern, book)
chapter_count = len(chapter_list)

print(f'Chapters List: {chapter_list}')
print(f'Total number of chapters: {chapter_count}')
# Out:
# Chapters List: ['Chapter 1', 'Chapter 2', 'Chapter 3', 'Chapter 4', 'Chapter 5', 'Chapter 6', 'Chapter 7', 'Chapter 8', 'Chapter 9', 'Chapter 10']
# Total number of chapters: 10
